# %%
import os

# %%
curr_dir=os.getcwd()# to obtain current working directory
curr_dir

# %%
os.listdir(r'c:\\Users\\LAPTOPS24\\Desktop\\Data science\\OS') # to obtain files in directory

# %%
os.mkdir("Demo")# to create folder

# %%
os.makedirs("user\\demo\\hi") # to create multiple dir

# %%
os.rename("Demo","Demo1")# to rename dir

# %%
os.chdir(r'c:\\Users\\LAPTOPS24\\Desktop\\Data science') # to change dir

# %%
os.listdir(os.getcwd())

# %%
path=r'c:\\Users\\LAPTOPS24\\Desktop' # to check wheather dir exist or not
os.path.isdir(path)
# Out:
# True

# %%
# to check wheather file exist or not
os.path.isfile(r"C:\Users\LAPTOPS24\Desktop\Data science\OS\basic.ipynb")
# Out:
# True

# %%
# to join to path
path1=r"C:\Users\LAPTOPS24\Desktop\Data science"
path2=r"OS"
os.listdir(os.path.join(path1,path2))
# Out:
# ['basic.ipynb', 'Demo1', 'user']

# %%
os.rmdir()# to remove dir
os.remove()# to remove file
