# %%
import numpy as np

# %%
print(np.__version__)

# %%
arr= np.array([1,23,4,56,7,86])
arr

# %%
lst =[12,2,3,4,5,6,7]
arr=np.array(lst)
arr

# %%
lst=list(range(1,20))
lst

# %%
arr=np.arange(10)
arr

# %%
arr= np.zeros(10) # to create array of zeros
arr=np.ones(10)  # to create array of ones
np.ones(10,20)# 2d array
arr

# %%
arr = np.arange(60)
arr=arr.reshape(12,5)
print(arr)
print(arr.dtype)#  data type
print(arr.size)# size of array
print(arr.ndim)# dim of arr 
print(arr.shape)# shape

# %%
print(arr[-1][-1]) # last element
print(arr[::-1])  # reverse

# %%
print(arr[4][2])
print(arr[4][3])
print(arr[5][2])
arr[0][0]=100
arr
