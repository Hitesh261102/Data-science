# %%
#constructor
class Collage:
    def __init__(self):
        print("hello")
st=Collage()

# %%
class Collage:
    collage_name="Bkbiet" # class variable

    def __init__(self,name,classes,collage="Bkbiet"):
       self.name=name   #instance variable
       self.classes=classes
       self.collage=collage
    def amount(self):
        amounts=10000
        print(f"my name is {self.name},amount id{amounts}")
        
st=Collage(name="Hitesh",classes="2nd yr")
print(st.name)
print(st.classes)
print(st.collage)
st.amount()

# %%
class Vechile:
    def __init__(self,vechile_name,brand,price):
        self.vechile_name=vechile_name
        self.brand=brand
        self.price=price

    def vechile_detail(self):
         print(f"vechile:{self.vechile_name},brand:{self.brand},price:{self.price}")
    def start():
        pass
class Car(Vechile):
    pass
class Bike(Vechile):
    pass
veh=Vechile(vechile_name="car",brand="xyz",price=100000)
veh.vechile_detail()
# Out:
# vechile:car,brand:xyz,price:100000
