# %%
# syntax
# def function_name():
    # pass

#pass is keyword used as placeholder for later initalization

# %%
def add(a,b):
    return a+b
add(10,20)

# %%
def vote(age):
    if age>=18:
        print("you can cast a vote")
    else:
        print("you cannot vote")
vote(18)

# %%
def discount(amount):
    if amount<2000:
       print("No discount")
    elif amount<=5000:
        print("you got 10% discount,amount after discount is",amount-(amount/10))
    else:
        print("you got 20% discount,amount after discount is",amount-(amount/5))
    print("Thanks for shopping")
dicount(10000)

# %%
def discount(amount):
    if amount<2000:
