# %%
# https://codeshare.io/a3wW31
file=open("abc","r")
print(file.read())
file.close()

# %%
with open("abc","r") as file:
    # print(file.read())
    # print(file.readline())
    print(file.readlines())

# %%
file=open("intro.txt","w")
file.write("hello mera nam Hitesh hai")
file.close()

# %%
with open("intro.txt","r") as file:
    print(file.read())

# %%
file=open("intro.txt","a")
file.write(f"\nhello mera nam Hitesh hai")
file.close()

# %%
with open("intro.txt","r") as file:
    print(file.read())
