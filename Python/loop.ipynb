# %%
name="hitesh"
for i in name:
    print(i,end=" ")

# %%
lst=[1,2,3,4,5]
dct={"a":1,"b":2}
for i in lst:
    print(i)
    
for k,i in dct.items():
    print(k,i)

# %%
tpl=(1,2,3)
for i in tpl:
    print(i,end=" ")

# %%
lst=[1,2,5,4,6,8,10,13,46]
even=[]
odd=[]
for i in lst:
    if i%2==0:
        even.append(i)
    else:
        odd.append(i)
print(even)
print(odd)
# Out:
# [2, 4, 6, 8, 10, 46]
# [1, 5, 13]

# %%
for i in range(10):
    if i==5:
        break
    else:
        print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
user= {
    "Alice": "A1!ice2024",
    "Bob": "B0b#Secure9",
    "Charlie": "Ch@rlie77",
    "David": "Dav!dX123",
    "Emma": "Emm@Pass88",
    "Frank": "Fr#nk2025",
    "Grace": "Gr@ceSecure1",
    "Henry": "HenrY!456",
    "Isabella": "Isa#Bella99",
    "Jack": "J@ckStrong7",
    "Karen": "Kar3n!Pass",
    "Liam": "Li@m2026X",
    "Mia": "Mi@Safe321",
    "Noah": "No@hPass88",
    "Olivia": "Ol!via2024",
    "Peter": "Pet#rSecure5",
    "Quinn": "Qu!nnX789",
    "Ryan": "Ry@nStrong12",
    "Sophia": "Sophi@Pass44",
    "Thomas": "Th0mas#Safe"
}
name=input("enter name:")
for k,v in user.items():
    if k==name:
        print(v)
        break
# Out:
# Pet#rSecure5

# %%
i=1
while(i<=10):
    print(i*2)
    if i*2==10:
        break
    i+=1
# Out:
# 2
# 4
# 6
# 8
# 10
