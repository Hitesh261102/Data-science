# %%
a=10
b=0
print(a/b)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 a=10
#       2 b=0
# ----> 3 print(a/b)
#
# ZeroDivisionError: division by zero

# %%
try:
    a=int(input("enter a number"))
    b=int(input("enter a number"))
    print(a/b)
except ZeroDivisionError as e:
    print(e)
# Out:
# division by zero

# %%
a=10
b="abc"
print(a+b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 a=10
#       2 b="abc"
# ----> 3 print(a+b)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
try:
    a=int(input("enter a number"))
    b=int(input("enter a number"))
    print(a+b)
except ValueError as e:
    print(e)
# Out:
# invalid literal for int() with base 10: '1w'

# %%
lst=[1,2,3,4]
print(lst[8])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 lst=[1,2,3,4]
# ----> 2 print(lst[8])
#
# IndexError: list index out of range

# %%
lst=[1,2,3,4]
try:
    print(lst[8])
except IndexError as e:
    print(e)
# Out:
# list index out of range

# %%
try:
    a=int(input("enter a number"))
    b=int(input("enter a number"))
    print(a/b)
except Exception as e:
    print(e)
else:
    print("hello")
finally:
    print("hello")
# Out:
# division by zero
# hello

# %%
# https://codeshare.io/amg4eX

# %%
class InvalidAgeError(Exception):
    pass
try:
    age=17
    if age<18:
        raise InvalidAgeError("no vote")
    else:
        print("can vote")
except InvalidAgeError as e:
    print(e)
# Out:
# no vote

# %%
# class InvalidEmailError(Exception):
    # pass
# try:
# email="hitesh@gmail.com"
# idx=email.index["@"]

# if email[idx,]=="gmail.com":
        # print("valid")
    # else:
        # raise InvalidEmailError("Invalid")
# except InvalidEmailError as e:
    # print(e)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 5
#       1 # class InvalidEmailError(Exception):
#       2     # pass
#       3 # try:
#       4 email="hitesh@gmail.com"
# ----> 5 idx=email.index["@"]
#       6
#       7 if email[idx,]=="gmail.com":
#       8         print("valid")
#
# TypeError: 'builtin_function_or_method' object is not subscriptable
